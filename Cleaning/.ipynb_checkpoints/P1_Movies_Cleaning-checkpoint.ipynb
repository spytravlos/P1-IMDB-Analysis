# %% [markdown]
# # Data Reading and Cleaning

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/traulosspyros/Desktop/Big Blue Data Academy/spyros-travlos-exercises/P1-Movies/Data/IMDb movies.csv')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description avg_vote votes   budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154      NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $ 2250
# 2  Two men of high rank are both wooing the beaut...      5.8   188      NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $ 45000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85855 non-null  object
#  1   title                  85855 non-null  object
#  2   original_title         85855 non-null  object
#  3   year                   85855 non-null  object
#  4   date_published         85855 non-null  object
#  5   genre                  85855 non-null  object
#  6   duration               85855 non-null  int64
#  7   country                85791 non-null  object
#  8   language               85022 non-null  object
#  9   director               85768 non-null  object
#  10  writer                 84283 non-null  object
#  11  production_company     81400 non-null  object
#  12  actors                 85786 non-null  object
#  13  description            83740 non-null  object
#  14  avg_vote               85855 non-null  float64
#  15  votes                  85855 non-null  int64
#  16  budget                 23710 non-null  object
#  17  usa_gross_income       15326 non-null  object
#  18  worlwide_gross_income  31016 non-null  object
#  19  metascore              13305 non-null  float64
#  20  reviews_from_users     78258 non-null  float64
#  21  reviews_from_critics   74058 non-null  float64
# dtypes: float64(4), int64(2), object(16)
# memory usage: 14.4+ MB

# %%
type(data['date_published'][0])
# Out:
# str

# %% [markdown]
# ### We need to:
# ### 1) convert date_published into date format

# %%
import datetime

# %%
data['date_published'] = data['date_published'].replace('[a-zA-z]', '',regex = True)
data.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description avg_vote votes   budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154      NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $ 2250
# 2  Two men of high rank are both wooing the beaut...      5.8   188      NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $ 45000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %%
data['date_published'] = pd.to_datetime(data['date_published'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85855 non-null  object
#  1   title                  85855 non-null  object
#  2   original_title         85855 non-null  object
#  3   year                   85855 non-null  object
#  4   date_published         85855 non-null  datetime64[ns]
#  5   genre                  85855 non-null  object
#  6   duration               85855 non-null  int64
#  7   country                85791 non-null  object
#  8   language               85022 non-null  object
#  9   director               85768 non-null  object
#  10  writer                 84283 non-null  object
#  11  production_company     81400 non-null  object
#  12  actors                 85786 non-null  object
#  13  description            83740 non-null  object
#  14  avg_vote               85855 non-null  float64
#  15  votes                  85855 non-null  int64
#  16  budget                 23710 non-null  object
#  17  usa_gross_income       15326 non-null  object
#  18  worlwide_gross_income  31016 non-null  object
#  19  metascore              13305 non-null  float64
#  20  reviews_from_users     78258 non-null  float64
#  21  reviews_from_critics   74058 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(15)
# memory usage: 14.4+ MB

# %% [markdown]
# ### 2) convert budget, usa_gross_income, worlwide_gross_income, year into numeric format

# %%
#worlwide_gross_income
data['worlwide_gross_income'] = data['worlwide_gross_income'].fillna(0) #we replace nan with 0 here as to not lose data for other examinations

# %%
data['worlwide_gross_income'] = data['worlwide_gross_income'].replace('[^\d\.]', '', regex = True)

# %%
data['worlwide_gross_income'] = pd.to_numeric(data['worlwide_gross_income'])

# %%
#usa_gross_income
data['usa_gross_income'] = data['usa_gross_income'].fillna(0)#we replace nan with 0 here as to not lose data fo
data['usa_gross_income'] = data['usa_gross_income'].replace('[^\d\.]', '', regex = True)
data['usa_gross_income'] = pd.to_numeric(data['usa_gross_income'])

# %%
#budget
data['budget'] = data['budget'].fillna(0)#we replace nan with 0 here as to not lose data fo
data['budget'] = data['budget'].replace('[^\d\.]', '', regex = True)
data['budget'] = pd.to_numeric(data['budget'])

# %%
data['year'] = data['year'].replace('[^\d\.]', '', regex = True)
data['year'] = pd.to_numeric(data['year'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85855 non-null  object
#  1   title                  85855 non-null  object
#  2   original_title         85855 non-null  object
#  3   year                   85855 non-null  int64
#  4   date_published         85855 non-null  datetime64[ns]
#  5   genre                  85855 non-null  object
#  6   duration               85855 non-null  int64
#  7   country                85791 non-null  object
#  8   language               85022 non-null  object
#  9   director               85768 non-null  object
#  10  writer                 84283 non-null  object
#  11  production_company     81400 non-null  object
#  12  actors                 85786 non-null  object
#  13  description            83740 non-null  object
#  14  avg_vote               85855 non-null  float64
#  15  votes                  85855 non-null  int64
#  16  budget                 85855 non-null  int64
#  17  usa_gross_income       85855 non-null  int64
#  18  worlwide_gross_income  85855 non-null  int64
#  19  metascore              13305 non-null  float64
#  20  reviews_from_users     78258 non-null  float64
#  21  reviews_from_critics   74058 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(6), object(11)
# memory usage: 14.4+ MB

# %%
data['usa_gross_income'] = data['usa_gross_income'].floordiv(1000000)
data['worlwide_gross_income'] = data['worlwide_gross_income'].floordiv(1000000)
data['budget'] = data['budget'].floordiv(1000000)

# %%
data.sample(20)
# Out:
#       imdb_title_id                                             title  \
# 15337     tt0068190  Le avventure di Alice nel paese delle meraviglie
# 70680     tt3298690                                        Dubrovskiy
# 44322     tt0380277                                       The Cookout
# 66717     tt2369135                                    Need for Speed
# 69725     tt3077214                                       Suffragette
# 64434     tt2088950                                This Is Your Death
# 28356     tt0110847                                      Non ho paura
# 26020     tt0102190                                        Karniggels
# 36075     tt0201869                                         O pseftis
# 50837     tt0855843                            Jas sum od Titov Veles
# 70402     tt3224288                                 Beyond the Clouds
# 73626     tt4075458                                      Beyond Sleep
# 13468     tt0062898                                 Il dottor Faustus
# 68031     tt2608030                                            Loaded
# 75855     tt4824308              God's Not Dead 2 - Dio non è morto 2
# 76237     tt4943322                               Il tenente ottomano
# 68908     tt2866360                 Coherence - Oltre lo spazio tempo
# 821       tt0020502                                L'ondata dei forti
# 26943     tt0105531                                   Tango argentino
# 71224     tt3439890                                       Born to Win
#
#                          original_title  year date_published  \
# 15337  Alice's Adventures in Wonderland  1972     1973-04-22
# 70680                        Dubrovskiy  2014     2014-03-06
# 44322                       The Cookout  2004     2004-09-03
# 66717                    Need for Speed  2014     2014-03-13
# 69725                       Suffragette  2015     2016-03-03
# 64434                This Is Your Death  2017     2017-09-15
# 28356                 Playing Dangerous  1995     1995-04-29
# 26020                        Karniggels  1991     1991-11-14
# 36075                         O pseftis  1968     1968-03-18
# 50837            Jas sum od Titov Veles  2007     2009-03-04
# 73626  Reinout Scholten van Aschat, Jakop Ahlbom, Mar...
# 13468  Richard Burton, Elizabeth Taylor, Andreas Teub...
# 68031  Patrick John Flueger, Kumail Nanjiani, Andrew ...
# 75855  Jesse Metcalfe, Robin Givens, Melissa Joan Har...
# 76237  Michiel Huisman, Hera Hilmar, Josh Hartnett, B...
# 68908  Emily Baldoni, Maury Sterling, Nicholas Brendo...
# 821    Renée Adorée, Tom Keene, George Fawcett, Willi...
# 26943  Mija Aleksic, Predrag 'Miki' Manojlovic, Nikol...
# 71224  Greg Kriek, Leoné Pienaar, Marie Cronjé, Cobus...
#
#                                              description avg_vote   votes  \
# 15337  Alice (Fiona Fullerton) falls down a rabbit ho...      5.8    1500
# 70680  A modern take on the classic novel by Alexande...      5.1     307
# 44322  Todd Anderson's life changes overnight when he...      3.7    2738
# 66717  Fresh from prison, a street racer who was fram...      6.4  161017
# 69725  In 1912 London, a young working mother is galv...      6.9   37288
# 64434  An unsettling look at reality T.V. where a dis...      5.6    4185
# 28356  A young scientific whiz (Mikey LeBeau) virtual...      3.9     292
# 26020  The young policeman Koeppe just left the acade...      6.8     497
# 36075  Indebted to the ocean liner's doctor, a stowaw...      5.3     109
# 50837  Three sisters living in an ancient city known ...      6.2     570
# 70402  When on the run from the cops , Amir finds his...      7.0    1881
# 73626  A young geologist ventures out into the vast t...      6.1     739
# 13468  A man sells his soul to the devil in order to ...      5.6     919
# 68031  Three estranged high school friends reunite fo...      5.5     750
# 75855  When a high school teacher is asked a question...      4.4   11200
# 76237  This movie is a love story between an idealist...      6.6   24058
# 68908  Strange things begin to happen when a group of...      7.2  103653
# 821    California's gold dicovery in 1848 draws a "ti...      6.4     170
# 26943  A boy who is helping lonely, elderly people re...      7.1     689
# 71224  A true story of how God turns the hurt, frustr...      5.4     186
#
#        budget  usa_gross_income  worlwide_gross_income  metascore  \
# 15337       2                 0                      0        NaN
# 70680       2                 0                      1        NaN
# 44322       0                11                     12       15.0
# 66717      66                43                    203       39.0
# 69725      14                 4                     31       66.0
# 64434       0                 0                      0       35.0
# 28356       0                 0                      0        NaN
# 26020       0                 0                      0        NaN
# 36075       0                 0                      0        NaN
# 50837       0                 0                      0        NaN
# 70402       0                 0                      0       55.0
# 73626       0                 0                      0        NaN
# 13468       0                 0                      0        NaN
# 68031       0                 0                      0        NaN
# 75855       5                20                     24       22.0
# 76237      40                 0                      0       26.0
# 68908       0                 0                      0       65.0
# 821         0                 0                      0        NaN
# 26943       0                 0                      0        NaN
# 71224       0                 0                      0        NaN
#
#        reviews_from_users  reviews_from_critics
# 15337                34.0                  12.0
# 70680                 NaN                   NaN
# 44322                22.0                  21.0
# 66717               403.0                 334.0
# 69725               135.0                 252.0
# 64434                48.0                  31.0
# 28356                 3.0                   2.0
# 26020                 3.0                   2.0
# 36075                 NaN                   NaN
# 50837                 4.0                  11.0
# 70402                31.0                  57.0
# 73626                 2.0                   8.0
# 13468                31.0                  12.0
# 68031                 2.0                   2.0
# 75855               164.0                  45.0
# 76237               133.0                  43.0
# 68908               320.0                 203.0
# 821                   7.0                   2.0
# 26943                 2.0                   2.0
# 71224                 3.0                   3.0
#
# [20 rows x 22 columns]

# %%
data.to_csv('/Users/traulosspyros/Desktop/Big Blue Data Academy/spyros-travlos-exercises/P1-Movies/Data/IMDb movies_Cleaned.csv', index = False)
